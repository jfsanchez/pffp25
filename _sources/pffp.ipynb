# %% [markdown]
# # Gráfica 1

# %%
from matplotlib import pyplot as plt 

Grupo = ['1ESO', '2ESO', '3ESO', '4ESO', '1BACH', '2BACH'] 
Idade = [13, 14, 15, 16, 17, 18] 

plt.bar(Grupo, Idade)
plt.show()

# %% [markdown]
# # Gráfica 2

# %%
x = [1, 2, 3, 5, 8]
y = [11, 21, 32, 51, 83]

plt.scatter(x, y)
plt.show()
